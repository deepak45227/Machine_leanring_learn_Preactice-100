# %% [markdown]
# # EDA
# <h2>Univarient_Analysis</h2>
# <p>when we do analysis of single variable we called it unvi-analy</p>
# we can say every column as variable
# if we do for two variable we called it Bivarient Analysis, and for more variable we called it multi varient analysis
# <p> For this we first know the nature of col is that numerical(name , age, height etc) or categorical (gender , college, branch) </p>

# %%
import pandas as pd
import seaborn as sns 
import matplotlib.pyplot as plt

# %%
sns.set_theme()

# %%
df=pd.read_csv(r"C:\Users\ACER\OneDrive\Desktop\DATA\dataset_titanic\Titanic-Dataset.csv")

# %%
df.head(6)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# ...

# %%
df.shape
# Out:
# (891, 12)

# %% [markdown]
# <h1>categorical</h1>

# %% [markdown]
# <h3>a.Countplot</h3>

# %%
sns.countplot(data=df, x='Survived')
# df["Survived"].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Survived', ylabel='count'>

# %%
df["Survived"].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Survived'>

# %%
sns.countplot(data=df,x='Pclass')
# Out:
# <Axes: xlabel='Pclass', ylabel='count'>

# %%
sns.countplot(df['Embarked'])
# Out:
# <Axes: xlabel='count', ylabel='Embarked'>

# %% [markdown]
# <h3>piechart</h3>

# %%
df["Survived"].value_counts().plot(kind="pie",autopct='%.2f')
# Out:
# <Axes: ylabel='count'>

# %%
df["Pclass"].value_counts().plot(kind="pie",autopct='%.2f')
# Out:
# <Axes: ylabel='count'>

# %%
df["Sex"].value_counts().plot(kind="pie",autopct='%.2f')
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# # Numrical Data

# %% [markdown]
# <h3>a.Histogram

# %%
plt.hist(df['Age'],bins=5)
# Out:
# (array([100., 346., 188.,  69.,  11.]),
#  array([ 0.42 , 16.336, 32.252, 48.168, 64.084, 80.   ]),
#  <BarContainer object of 5 artists>)

# %% [markdown]
# <h3>b. Displot

# %%
sns.distplot(df['Age'])
# Out:
# C:\Users\ACER\AppData\Local\Temp\ipykernel_20088\3255828239.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Age'])
# <Axes: xlabel='Age', ylabel='Density'>

# %% [markdown]
# <h3>c. Boxplot

# %%
sns.boxplot(data=df,x='Fare')
# Out:
# <Axes: xlabel='Fare'>

# %%
sns.boxplot(data=df,x='Age')
# Out:
# <Axes: xlabel='Age'>

# %%
df['Age'].mean()
# Out:
# np.float64(29.69911764705882)

# %%
df['Age'].median()
# Out:
# np.float64(28.0)

# %%
df['Age'].mode()
# Out:
# 0    24.0
# Name: Age, dtype: float64

# %%
df['Age'].skew()
# Out:
# np.float64(0.38910778230082704)
